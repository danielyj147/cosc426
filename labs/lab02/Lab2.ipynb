# %% [markdown]
# # Lab 2: Minimal Pair practice with Implicit Causality
# ### COSC 426: Fall 2025, Colgate University
#
# Use this notebook to answer the questions in `Lab2.md`. For answers where you are looking at data files generated by the `evaluate` or `analyze` modes, you should load the data into the ipynb notebook and proceed from there.
#
# ## Daniel Jeong, David Reyes

# %% [markdown]
# ## Part 1
#
# Answer each of the questions for Part 1 in the respective markdown chunks below

# %% [markdown]
# Does Distil bert learnt he implicit casuality.
#
# output
# subject / object
#
#
# <!-- - she frightened her because she was terrifying. -->
# - She frightened her because she was terrifying.
#
#
# [1] is more expected / prob of "she"
# 1. Sally frightened Mary because she was terrifying.
# 2. Marcus frightened Mary becuase she was terrifying.
#
# [3] is more expected / prob of "she"
# 3. Sally feared Marry because she was terrifying
# 4. Sally feared Marcus because she was terrifying

# %% [markdown]
# #### Question 1
#
# For "frightened"
#
# 1. Sally frightened Mary because she was terrifying.
# 2. Marcus frightened Mary becuase she was terrifying.
#
# ---
# For "feared"
#
# 1. Sally feared Marry because she was terrifying
# 2. Sally feared Marcus because she was terrifying

# %% [markdown]
# #### Question 2
#
# [1] is more expected / prob of "she"
# 1. Sally frightened Mary because she was terrifying.
# 2. Marcus frightened Mary becuase she was terrifying.
#
# [3] is more expected / prob of "she"
# 3. Sally feared Marry because she was terrifying
# 4. Mary feared Marcus because she was terrifying

# %% [markdown]
# #### Question 3
#
# **Type your answer below this**

# %% [markdown]
# ## Part 2
#
# Answer the questions in Part 2. Feel free to add as many markdown or code chunks as you need.

# %%
import pandas as pd 

df = pd.read_csv('./results/resutls_bypair.tsv', delimiter="\t")
df
# Out:
#    Unnamed: 0                  model     type  pairid  expected  unexpected  \
# 0           0  distilbert/distilgpt2   object       3  0.385933    0.010370
# 1           1  distilbert/distilgpt2   object       4  0.132806    0.018329
# 2           2  distilbert/distilgpt2  subject       1  0.460124    0.241009
# 3           3  distilbert/distilgpt2  subject       2  0.398773    0.347421
#
#        diff   acc
# 0  0.375563  True
# 1  0.114476  True
# 2  0.219116  True
# 3  0.051353  True

# %% [markdown]
# 1. Does distilbert/distilgpt2 learn the subject IC verb bias for frightened and bored?
#
# Yes, since the `acc` column holds true for all the rows the model has learned the subject IC verb bias.
#
# 2. Does distilbert/distilgpt2 learn the object IC verb bias for feared and believed?
#
# Yes, since the `acc` column holds true for all the rows the model has learned the object IC verb bias.

# %% [markdown]
# ## Part 3
#
# Answer each of the questions for Part 1 in the respective markdown chunks below

# %% [markdown]
# #### Question 1
#
# We'll first swap the names and use a male and female name. Then, we'll switch the pronoun to "he" using sentences structured similarly to those in our current dataset. After that, we'll evaluate for gender and check which pronoun has a greater average expected value on averageIC.

# %% [markdown]
# #### Question 2
#
# **Type your answer below this**

# %% [markdown]
# We'll maintain a similar sentence structure but will swap one name for a non-name (like "the firefighter" or "her") and then check if these sentences are preferred over those with proper nouns.

# %% [markdown]
# #### Question 3
#
# Are you confident in your clam?
#
# No, we should have more sentences in our dataset with diffrent verbs, lengths and structures to be more confident.
